# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_boston
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

boston = load_boston()
df = pd.DataFrame(data = boston.data, columns = boston.feature_names)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df.hist(column = ['DIS', 'RAD'], bins=30)
reg = LinearRegression()
X = df.loc[:,['DIS', 'RAD']]
Y = pd.DataFrame(data = boston.target)
reg.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
prediction = reg.predict(X)
plt.scatter(X['DIS'], Y)

# %%
plt.plot(X['DIS'], prediction)

# %%
prediction = reg.predict(X)
plt.scatter(X['RAD'], Y)

# %%
plt.plot(X['RAD'], prediction)

# %%
print("Boston house prices increase as the value of index of accessibility to radial highways decreases linearly")
# Out:
# Boston house prices increase as the value of index of accessibility to radial highways decreases linearly

# %%
print("The difference between the highest and the lowest prices decreases with weighted distances to five Boston employment centres")
# Out:
# The difference between the highest and the lowest prices decreases with weighted distances to five Boston employment centres
